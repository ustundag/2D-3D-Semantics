# %%
from PIL import Image
import glob
from scipy.io import savemat, loadmat 
from IPython.display import display, clear_output
import pandas as pd
import numpy as np
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import normalized_mutual_info_score, confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Find actual cluster types and ground truth labels. E.g. Area3 has 6 different rooms as follows;
#
# {'WC', 'conferenceRoom', 'hallway', 'lounge', 'office', 'storage'}

# %%
def find_ground_truth_clusters_and_labels():
    path = "C:\\Users\\ustundag\\GitHub\\2D-3D-Semantics\\area_3\\data\\semantic\\*.png"
    labels = []

    for path in glob.glob(path):
        s = path.split('_')
        room = s[3]
        labels.append(str(room))
    
    labels = [l.replace('WC'            , '0') for l in labels]
    labels = [l.replace('conferenceRoom', '1') for l in labels]
    labels = [l.replace('hallway'       , '2') for l in labels]
    labels = [l.replace('lounge'        , '3') for l in labels]
    labels = [l.replace('office'        , '4') for l in labels]
    labels = [l.replace('storage'       , '5') for l in labels]

    return np.asarray(list(map(int, labels)), dtype=np.int64)

# %%
def get_room_type(i):
    if i == 0: return 'WC'
    if i == 1: return 'conferenceRoom'
    if i == 2: return 'hallway'
    if i == 3: return 'lounge'
    if i == 4: return 'office'
    if i == 5: return 'storage'

# %%
# Assign ground truth labels
labels_gt = find_ground_truth_clusters_and_labels();

# %% [markdown]
# A function to save images as numpy array to reduce computational cost by converting to grayscale and resizing.

# %%
def save_images():
    path = "C:\\Users\\ustundag\\GitHub\\2D-3D-Semantics\\area_3\\data\\semantic\\*.png"
    images = []
    for path in glob.glob(path):
        clear_output(wait=True)
        img = Image.open(path).convert('L')
        img = np.array(img.resize((90, 90), Image.NEAREST))/255
        images.append(img.flatten())
        display(str(len(images)) + " / 3704")

    savemat('noXYZ_area_3_no_xyz_data_semantic_90x90.mat', {'semantic': np.array(images)})

# %%
save_images()
# Out:
# '3704 / 3704'

# %%
mat = loadmat("C:\\Users\\ustundag\\GitHub\\2D-3D-Semantics\\noXYZ_area_3_no_xyz_data_semantic_90x90.mat")
images = mat["semantic"]
X = images / 255.0

# %%
plt.figure(figsize=(8, 8))
for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.imshow(images[i].reshape([90, 90]), cmap='gray')

# %% [markdown]
# ### PCA Analysis
# We see that the first 3 components have huge impact on images, then then second 3 components follow them.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, normalize
# %config InlineBackend.figure_format='retina'

# Standardize the data to have a mean of ~0 and a variance of 1
#X = StandardScaler().fit_transform(images)
#X = normalize(X)

# Create a PCA instance
#pca = PCA(n_components = 50) # DBSCAN finds only 1 cluster with 3!
pca = PCA(.80) # DBSCAN finds 6 cluster with 0.8!
PCA_components = pca.fit_transform(X)
# Plot the explained variances
# pca has 149 components
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Save components as a DataFrame
PCA_components = pd.DataFrame(PCA_components)

# %% [markdown]
# ### KMEANS Analysis
# Determining the best number of clusters; So, 4 is the elbow point for cluster numbers. Maybe 5 or even 6?

# %%
from sklearn.cluster import KMeans

ks = range(1, 10)
inertias = []
for k in ks:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)
    # Fit model to first 10 components
    model.fit(PCA_components)
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(ks, inertias, '-o', color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
# Apply kmeans and plot 3D
n_clusters = 6
kmeans = KMeans(n_clusters).fit(PCA_components)
labels_kmeans = kmeans.labels_

fig = plt.figure(1, figsize=(8, 6))
ax  = fig.add_subplot(111, projection='3d')
axs = ax.scatter(PCA_components[0],
                 PCA_components[1], 
                 PCA_components[2], 
                 c=labels_kmeans.astype(np.float))

fig.colorbar(axs)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title("KMeans Clusters: " + str(n_clusters))
ax.dist = 10

plt.show()

# %%
normalized_mutual_info_score(labels_gt, labels_kmeans)
# Out:
# c:\python368-64\lib\site-packages\sklearn\metrics\cluster\supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.09864284156051359

# %% [markdown]
# ### DBSCAN Analysis
# Apply DBSCAN and plot 3D. It finds 6 clusters with eps=0.75, min_samples=14.

# %%
from sklearn.cluster import DBSCAN

# DBSCAN finds 6 clusters with PCA(.80), eps=0.75, min_samples=14
dbs = DBSCAN(eps=0.0095, min_samples=4)
labels_dbscan = dbs.fit_predict(PCA_components)+1

fig = plt.figure(1, figsize=(8, 6))
ax  = fig.add_subplot(111, projection='3d')
axs = ax.scatter(PCA_components[0],
                 PCA_components[1],
                 PCA_components[2],
                 c=labels_dbscan.astype(np.float))

fig.colorbar(axs)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title("DBSCAN Clusters: " + str(len(set(labels_dbscan))))
ax.dist = 10

plt.show()

# %%
normalized_mutual_info_score(labels_gt, labels_dbscan)
# Out:
# 0.08693726677662131

# %% [markdown]
# ### Distribute images to each cluster folder

# %%
import matplotlib
import os

def create_separate_cluster_folders():
    #Project lower dimension data onto original features
    approximation = pca.inverse_transform(PCA_components)
    #Approximation is 5000x1024
    print("approximation.shape:", approximation.shape)
    #Reshape approximation and X_norm to 3704x90x90 to see diff.
    approximation = approximation.reshape(-1, 90, 90)
    X_r = X.reshape(-1, 90, 90)

    for i in range(len(labels)):
        path = "cluster_" + str(labels[i])
        if not os.path.exists(path):
            os.mkdir(path)
        matplotlib.image.imsave(os.path.join(path, str(i) + '.png'), X_r[i], cmap='gray')

def create_one_folder_with_cluster_names():
    path = 'all_clusters'
    os.mkdir(path)
    for i in range(len(labels)):
        matplotlib.image.imsave(os.path.join(path, 'cluster_' + str(labels[i]) +'_img'+ str(i) + '.png'), X_norm[i], cmap='gray')

# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
# eps:0.0011 - min_samples:2 - cluster:6 - score:0.030304522989225542
# eps:0.0012 - min_samples:2 - cluster:6 - score:0.030304522989225542
# eps:0.0035 - min_samples:4 - cluster:7 - score:0.030245058062513593
# eps:0.0036 - min_samples:4 - cluster:8 - score:0.032700111943499637
# eps:0.0087 - min_samples:4 - cluster:5 - score:0.07661455038395211
# eps:0.0089 - min_samples:4 - cluster:5 - score:0.07552219311110445
# eps:0.0012 - min_samples:2 - cluster:6 - score:0.030304522989225542
# eps:0.0072 - min_samples:6 - cluster:6 - score:0.03930959722637163
# eps:0.0073 - min_samples:6 - cluster:6 - score:0.04322455605341925
# eps:0.0075 - min_samples:5 - cluster:6 - score:0.051619871650581524
# eps:0.0076 - min_samples:5 - cluster:6 - score:0.05240690832854979
# eps:0.0090 - min_samples:4 - cluster:6 - score:0.07686682783802287
# eps:0.0095 - min_samples:4 - cluster:6 - score:0.08693726677662131
# eps:0.0120 - min_samples:4 - cluster:6 - score:0.0783553370858012
# eps:0.0122 - min_samples:4 - cluster:6 - score:0.07366210931046144
# eps:0.0124 - min_samples:4 - cluster:7 - score:0.07261074014052235
# eps:0.0118 - min_samples:4 - cluster:5 - score:0.08115934899949416

for eps in np.arange(0.0100, 0.0200, 0.0002):
    for i in range(2,15):
        # DBSCAN finds 6 clusters with PCA(.80), eps=0.75, min_samples=14
        dbs = DBSCAN(eps=eps, min_samples = i)
        labels_dbscan = dbs.fit_predict(PCA_components)+1
        score = normalized_mutual_info_score(labels_gt, labels_dbscan)
        if 4 < len(set(labels_dbscan)) < 8 and score > 0.03:
            print('# eps:'+str(eps)+' - min_samples:'+str(i)+ ' - cluster:'+str(len(set(labels_dbscan))) + ' - score:' + str(score))

print('finished!')
# Out:
# # eps:0.011800000000000005 - min_samples:4 - cluster:5 - score:0.08115934899949416
# # eps:0.012000000000000005 - min_samples:4 - cluster:6 - score:0.0783553370858012
# # eps:0.012200000000000006 - min_samples:4 - cluster:6 - score:0.07366210931046144
# # eps:0.012400000000000007 - min_samples:4 - cluster:7 - score:0.07261074014052235
# # eps:0.012600000000000007 - min_samples:4 - cluster:6 - score:0.06783439351711858
# # eps:0.013000000000000008 - min_samples:4 - cluster:5 - score:0.06120858908421895
# # eps:0.013200000000000009 - min_samples:4 - cluster:6 - score:0.06133346957499512
# # eps:0.013400000000000009 - min_samples:4 - cluster:6 - score:0.05917026756709787
# # eps:0.01360000000000001 - min_samples:4 - cluster:5 - score:0.053784447923869515
# # eps:0.01380000000000001 - min_samples:4 - cluster:5 - score:0.05007610249025285
# # eps:0.01400000000000001 - min_samples:3 - cluster:7 - score:0.05007311109159459
# # eps:0.01400000000000001 - min_samples:4 - cluster:5 - score:0.04818708853045827
# # eps:0.01400000000000001 - min_samples:5 - cluster:5 - score:0.04926680444266106
# # eps:0.014200000000000011 - min_samples:3 - cluster:6 - score:0.044598861458462744
# # eps:0.014200000000000011 - min_samples:4 - cluster:6 - score:0.044839563761290724
# # eps:0.014200000000000011 - min_samples:5 - cluster:5 - score:0.04392055047885724
# # eps:0.014400000000000012 - min_samples:3 - cluster:6 - score:0.043220725819730854
# # eps:0.014400000000000012 - min_samples:4 - cluster:6 - score:0.043571625873331035
# # eps:0.014400000000000012 - min_samples:5 - cluster:5 - score:0.04116243140435017
# # eps:0.014600000000000012 - min_samples:3 - cluster:5 - score:0.04294649974600091
# # eps:0.014600000000000012 - min_samples:4 - cluster:5 - score:0.04402552631728586
# # eps:0.014600000000000012 - min_samples:5 - cluster:5 - score:0.04283296158721008
# # eps:0.014800000000000013 - min_samples:3 - cluster:6 - score:0.0428555372132916
# # eps:0.014800000000000013 - min_samples:5 - cluster:5 - score:0.040388453553643046
# # eps:0.015000000000000013 - min_samples:3 - cluster:6 - score:0.042399406198275987
# # eps:0.015000000000000013 - min_samples:5 - cluster:5 - score:0.0378769408670714
# # eps:0.015200000000000014 - min_samples:3 - cluster:6 - score:0.039869238054218464
# # eps:0.015400000000000014 - min_samples:3 - cluster:6 - score:0.03848306700172918
# # eps:0.015600000000000015 - min_samples:3 - cluster:6 - score:0.03518094513802825
# finished!
